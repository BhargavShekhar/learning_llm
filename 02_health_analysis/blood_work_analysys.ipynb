# %%
# Work flow for a specific task -> heath analysis

from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import SystemMessage, HumanMessage

load_dotenv()

llm = ChatGoogleGenerativeAI(
    model="gemini-3.5-flash"
)

# %%
with open("blood_work.txt", "r") as f:
    blood_report = f.read()
print(blood_report[:200])
# Out:
# Patient: Rajesh Sharma, Age 48, Male
# Date: May 7, 2026
#
# COMPLETE BLOOD COUNT (CBC)
# --------------------------
# Hemoglobin:        15.1 g/dL        (Normal: 13.5–17.5)
# Hematocrit:        44%

# %%
extraction_prompt = f"""
You are a medical data extraction assistant.

From the blood report below, extract ALL test values and classify each one as HIGH, LOW, or NORMAL
based on the reference ranges provided in the report.

Format your response as:
- Test Name: value | Status: HIGH/LOW/NORMAL | Reference Range: range

Blood Report:
{blood_report}
"""

extraction_response = llm.invoke(extraction_prompt)
extracted_values = extraction_response.text;

print("=== STAGE 1: EXTRACTED VALUES ===")
print(extracted_values)
# Out:
# === STAGE 1: EXTRACTED VALUES ===
# - Hemoglobin: 15.1 g/dL | Status: NORMAL | Reference Range: 13.5–17.5
# - Hematocrit: 44% | Status: NORMAL | Reference Range: 41–53%
# - WBC: 6.8 x10^3/uL | Status: NORMAL | Reference Range: 4.5–11.0
# - Platelets: 220 x10^3/uL | Status: NORMAL | Reference Range: 150–400
# - Total Cholesterol: 238 mg/dL | Status: HIGH | Reference Range: <200
# - LDL Cholesterol: 162 mg/dL | Status: HIGH | Reference Range: <100
# - HDL Cholesterol: 36 mg/dL | Status: LOW | Reference Range: >40
# - Triglycerides: 188 mg/dL | Status: HIGH | Reference Range: <150
# - Glucose (Fasting): 92 mg/dL | Status: NORMAL | Reference Range: 70–99
# - HbA1c: 5.3% | Status: NORMAL | Reference Range: <5.7%
# - Creatinine: 1.0 mg/dL | Status: NORMAL | Reference Range: 0.7–1.3
# - eGFR: 82 mL/min | Status: NORMAL | Reference Range: >60
# - ALT: 28 U/L | Status: NORMAL | Reference Range: 7–40
# - AST: 25 U/L | Status: NORMAL | Reference Range: 10–40
# - Bilirubin Total: 0.8 mg/dL | Status: NORMAL | Reference Range: 0.2–1.2

# %%
diet_prompt = f"""
You are a clinical nutritionist specializing in Indian dietary habits.

Based on the blood work analysis below, write:
1. A short health summary in 4-5 lines explaining the patient's condition in simple language
2. A short, practical Indian diet plan having only two sections:
   (1) Foods to avoid
   (2) Foods to eat more of

Do not include any other sections in the diet plan.

Blood Work Analysis:
{extracted_values}
"""

diet_response = llm.invoke(diet_prompt)
print("=== STAGE 2: HEALTH SUMMARY AND DIET PLAN ===")
print(diet_response.text)
# Out:
# === STAGE 2: HEALTH SUMMARY AND DIET PLAN ===
# ### Health Summary
# Your blood counts, blood sugar, liver, and kidney functions are completely normal and in excellent health. However, your lipid profile shows dyslipidemia, meaning your bad cholesterol (LDL), total cholesterol, and triglycerides are elevated, while your protective good cholesterol (HDL) is low. This pattern is common with typical Indian diets high in refined carbohydrates and unhealthy fats, and it can increase your long-term heart risk. Fortunately, this profile responds very well to targeted dietary modifications, specifically by replacing unhealthy fats and refined carbs with soluble fiber and healthy fats.
#
# ***
#
# ### (1) Foods to avoid
# *   **Refined Carbohydrates:** Maida (refined flour) items like naan, parotta, white bread, biscuits, rusk, and bakery items.
# *   **Deep-Fried Foods:** Samosas, pakoras, kachoris, puris, bhaturas, and namkeen (sev, bhujia) fried in reheated oils.
# *   **Unhealthy Fats & Sweets:** Traditional mithai made with vanaspati (dalda), commercial ghee, butter, and palm-oil-based processed foods.
# *   **High-Fat Dairy & Red Meat:** Full-fat milk, malai (cream), full-fat paneer, butter, and red meats (mutton).
# *   **Sugary Beverages:** Carbonated sodas, packaged fruit juices, and tea or coffee with excess white sugar.
#
# ### (2) Foods to eat more of
# *   **Soluble Fiber & Whole Grains:** Oats, daliya (broken wheat), ragi (finger millet), jowar (sorghum), bajra, and unpolished brown or red rice.
# *   **Plant Proteins & Legumes:** Whole dals (chilka moong, masoor, chana), sprouts, lobia (black-eyed peas), and kala chana.
# *   **Healthy Fats (to boost HDL):** Handful of unsalted walnuts and almonds daily, along with seeds like flaxseeds (alsi), chia seeds, and methi (fenugreek) seeds. Use cold-pressed mustard oil, sesame oil, or olive oil in moderation for cooking.
# *   **Low-Fat Dairy:** Double-toned milk, homemade curd (dahi) from low-fat milk, and buttermilk (chaas).
# *   **High-Fiber Vegetables:** Okra (bhindi), eggplant (baingan), bottle gourd (lauki), bitter gourd (karela), methi leaves, spinach, and raw salads eaten before meals.
